# %%
import pandas as pd

#Function to read in Excel to list
def READ_IN(EXCEL,lst):
    excel = pd.ExcelFile(EXCEL)
    df = excel.parse('Sheet1')
    lst.append(df)
    return df
lst_df = []

#Read in Excel Files to list

df1 = READ_IN('Tray 1M.xlsx',lst_df)
df2 = READ_IN('Tray 2M.xlsx', lst_df)
df3 = READ_IN('Tray 3M.xlsx', lst_df)
df4 = READ_IN('Tray 4.xlsx', lst_df)
df5 = READ_IN('Tray 5.xlsx', lst_df)
df6 = READ_IN('Tray 6M.xlsx', lst_df)
df7 = READ_IN('Tray 7M.xlsx', lst_df)
df8 = READ_IN('Tray 8M.xlsx', lst_df)
df8real = READ_IN('Tray M8_Real.xlsx', lst_df)
df11 = READ_IN('Tray M11 rerun.xlsx', lst_df)
df12 = READ_IN('Tray M12.xlsx', lst_df)
df14 = READ_IN('Tray M14.xlsx', lst_df)
df15 = READ_IN('Tray M15.xlsx', lst_df)
df16 = READ_IN('Tray M16.xlsx', lst_df)
df17 = READ_IN('Tray M17.xlsx', lst_df)
df18 = READ_IN('Tray M18.xlsx', lst_df)
df19 = READ_IN('Tray M19.xlsx', lst_df)
df20 = READ_IN('Tray M20.xlsx', lst_df)
df21 = READ_IN('Tray M21.xlsx', lst_df)
df22 = READ_IN('Tray M22.xlsx', lst_df)
df23 = READ_IN('Tray M23.xlsx', lst_df)
df25 = READ_IN('Tray M25.xlsx', lst_df)
df26 = READ_IN('Tray M26.xlsx', lst_df)
df27 = READ_IN('Tray M27.xlsx', lst_df)
df28 = READ_IN('Tray M28.xlsx', lst_df)
df29 = READ_IN('Tray M29.xlsx', lst_df)
df30 = READ_IN('Tray M30.xlsx', lst_df)
df31 = READ_IN('Tray M31.xlsx', lst_df)

#Adding Tray Numbers
column_head ='Tray Number'

for df_num in range(0,8):
    lst_df[df_num].insert(loc=0, column = column_head, value=df_num + 1)

lst_df[8].insert(loc=0, column = column_head, value= '8 Real')

for df_num in range(9,11):
    lst_df[df_num].insert(loc=0, column = column_head, value=df_num + 2)
    
for df_num in range(11,21):
    lst_df[df_num].insert(loc=0, column = column_head, value=df_num + 3)

for df_num in range(21,28):
    lst_df[df_num].insert(loc=0, column = column_head, value=df_num + 4)
    
#Combining Data and Saving
    
df_final = pd.concat(lst_df,sort = False)

df_final.to_excel("Final_ICP-MS.xlsx")
